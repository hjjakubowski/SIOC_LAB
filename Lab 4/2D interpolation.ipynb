# %%
import sys
sys.path.append(".../src")

# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from numpy.typing import NDArray
from skimage import io, transform, color
from src.kernels import sample_hold_kernel, nearest_neighbour_kernel
from src.interp import image_interpolate2d, image_interpolate2d_rgb
import matplotlib.pyplot as plt

# %%
grey_img = io.imread('image.png')
grey_img = transform.resize(grey_img, output_shape=(100,100))
io.imshow(grey_img)
grey_img.shape
# Out:
# (100, 100)

# %%
hn_interp = image_interpolate2d(grey_img, ratio=4, kernel_function=nearest_neighbour_kernel)
hs_interp = image_interpolate2d(grey_img, ratio=4, kernel_function=sample_hold_kernel)
plt.subplot(1, 2, 1)  
plt.imshow(hn_interp, cmap="gray") 
plt.title("Nearest Neighbour Kernel")


plt.subplot(1, 2, 2) 
plt.imshow(hs_interp, cmap="gray") 
plt.title("Sample Hold Kernel")

plt.tight_layout()

# %%
szczupak = io.imread('szczupak.jpg')
szczupak = color.rgb2gray(szczupak)
szczupak = transform.resize(szczupak, output_shape=(75,125))

io.imshow(szczupak)
szczupak.shape
# Out:
# (75, 125)

# %%
hn_interp = image_interpolate2d(szczupak, ratio=4, kernel_function=nearest_neighbour_kernel)
hs_interp = image_interpolate2d(szczupak, ratio=4, kernel_function=sample_hold_kernel)
plt.subplot(1, 2, 1)  
plt.imshow(hn_interp, cmap="gray") 
plt.title("Nearest Neighbour Kernel")


plt.subplot(1, 2, 2) 
plt.imshow(hs_interp, cmap="gray") 
plt.title("Sample Hold Kernel")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 hn_interp = image_interpolate2d(szczupak, ratio=4, kernel_function=nearest_neighbour_kernel)
#       2 hs_interp = image_interpolate2d(szczupak, ratio=4, kernel_function=sample_hold_kernel)
#       3 plt.figure(figsize=(12, 6))
#
# File c:\Users\huber\Desktop\ISA\Sem 3\SIOC\Lab 4\src\interp.py:14, in image_interpolate2d(image, ratio, kernel_function)
#       5 """
#       6 Interpolate image using 2D kernel interpolation
#       7 :param image: grayscale image to interpolate as 2D NDArray
#    (...)
#      10 :return: interpolated image as 2D NDArray
#      11 """
#      12 w = 1 * ratio
# ---> 14 img_rows, img_cols = image.shape
#      15 target_shape = (img_rows * ratio, img_cols * ratio)
#      17 image_grid = np.array([[row, col] for row in range(img_rows) for col in range(img_cols)])
#
# ValueError: too many values to unpack (expected 2)

# %%
szczupak = io.imread('szczupak.jpg')
szczupak = transform.resize(szczupak, output_shape=(75,125))

io.imshow(szczupak)
szczupak.shape
# Out:
# (75, 125, 3)

# %%
hn_interp = image_interpolate2d_rgb(szczupak, ratio=2, kernel_function=nearest_neighbour_kernel)
hs_interp = image_interpolate2d_rgb(szczupak, ratio=2, kernel_function=sample_hold_kernel)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)  
plt.imshow(hn_interp) 
plt.title("Nearest Neighbour Kernel")


plt.subplot(1, 2, 2) 
plt.imshow(hs_interp) 
plt.title("Sample Hold Kernel")
# Out:
# Text(0.5, 1.0, 'Sample Hold Kernel')
